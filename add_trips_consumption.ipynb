# %%
import numpy as ny
import pandas as pd

# %%
data = pd.read_csv("10_percent_weather.csv")
data["consumption_city_kWh"] = data["Trip Miles"].apply(lambda x:(x*28.09/100))
data["consumption_combined_kWh"] = data["Trip Miles"].apply(lambda x:(x*30.13/100))
data.head()
# Out:
#    Unnamed: 0                                   Trip ID Trip Start Timestamp  \
# 0           0  01fb7b0a39770bf4030110323f25e564bd46deb0  2019-01-01 00:00:00
# 1           1  01fb7b0a39770bf4030110323f25e564bd46deb0  2019-01-01 00:00:00
# 2           2  02de4893ce2de28b50976cc723f98cc8d325f9d5  2019-01-01 00:00:00
# 3           3  02de4893ce2de28b50976cc723f98cc8d325f9d5  2019-01-01 00:00:00
# 4           4  04d812ada11a1cd2d4b556f53574513a8fb3cea6  2019-01-01 00:00:00
#
#        Trip End Timestamp  Trip Seconds  Trip Miles  Trips Pooled  \
# 0  01/01/2019 12:00:00 AM         249.0         0.8             1
# 1  01/01/2019 12:00:00 AM         249.0         0.8             1
# 2  01/01/2019 12:15:00 AM         445.0         1.7             1
# 3  01/01/2019 12:15:00 AM         445.0         1.7             1
# 4  01/01/2019 12:00:00 AM         673.0         2.3             1
#
#    Pickup Centroid Latitude  Pickup Centroid Longitude  \
# ...

# %%
#data.drop(["Unnamed: 0","Trip ID", "Trips Pooled"], axis=1).to_csv("10_percent_consump.csv")
